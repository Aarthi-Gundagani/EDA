# %% [markdown]
# **Categorical to Numerical**

# %% [markdown]
# - It is very important to convert categorical data into numerical data
#
# - Because in Machine Learning models the input is in the form of numbers
#
# - ML models developed by maths, so passing english text data will not work
#
# - We have different types of methods are there to convert cat to num data
#
#    - Map method
#
#    - np.where method
#
#    - one hot encoder
#
#    - Label encoder

# %% [markdown]
# **Import the packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the data**

# %%
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
# categorical columns

visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **Map Method**
#
# - First get the unique labels for each column
#
# - create a dictionary by providing a values to each label
#
# - For example, case_status has two labels, we are providing two values
#
#     - Assign 0 for certified
#
#     - Assign 1 for Denied

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Denied':1,'Certified':0}   # Alphabetical order
d
# Out:
# {'Denied': 1, 'Certified': 0}

# %%
visa_df['case_status'].map(d)
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
df=pd.DataFrame(visa_df['case_status'].map(d))
df
# Out:
#        case_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                0
# ...            ...
# 25475            0
# 25476            0
# 25477            0
# 25478            0
# 25479            0
#
# [25480 rows x 1 columns]

# %%
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
d={'Denied':1,'Certified':0}   # Alphabetical order
visa_df['case_status'].map(d)
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['unit_of_wage'].unique()
# Out:
# array(['Hour', 'Year', 'Week', 'Month'], dtype=object)

# %%
d1={'Hour':0,'Monh':1,'Week':2,'Year':3}
d1
# Out:
# {'Hour': 0, 'Monh': 1, 'Week': 2, 'Year': 3}

# %%
visa_df['unit_of_wage'].map(d1)
# Out:
# 0        0.0
# 1        3.0
# 2        3.0
# 3        3.0
# 4        3.0
#         ...
# 25475    3.0
# 25476    3.0
# 25477    3.0
# 25478    3.0
# 25479    3.0
# Name: unit_of_wage, Length: 25480, dtype: float64

# %%
visa_df['unit_of_wage']=visa_df['unit_of_wage'].map(d1)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Task**
#
# - Read the data
#
# - Apply the loop
#
# - Iterate through columns
#
# -

# %%
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
len(visa_df['case_status'].unique())
# Out:
# 2

# %%
labels=list(visa_df['case_status'].unique())
values=[ i for i in range(len(labels))]
dict(zip(labels,values))
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
labels=list(visa_df['education_of_employee'].unique())
values=[ i for i in range(len(labels))]
dict(zip(labels,values))
# Out:
# {'High School': 0, "Master's": 1, "Bachelor's": 2, 'Doctorate': 3}

# %%
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
cols=visa_df.select_dtypes(include='object').columns
for i in cols:
    labels=list(visa_df[i].unique())
    values=[ i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **Label encoder**
#
#   - Label encoder is a package under **sickit Learn**
#
#   - Sickit-learn is heart of Machine Learning
#
#   - Inside sickit-learn we have a method called **Preprocessing**
#
#   - Under preprocessing, we have label encoder
#
#   - we will write sickit-learn as sk-learn
#
#   - Any sk-learn package, we have 3 steps:
#
#       - Step-1: Read the package
#
#       - Step-2: Save the package
#
#       - Step-3: Apply Fit transform

# %%
# read the data

visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
# Step-1: Read the package
from sklearn.preprocessing import LabelEncoder
# Step-2: Save the package
le=LabelEncoder()
# Step-3: Apply Fit transform
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Step-1: Read the package
from sklearn.preprocessing import LabelEncoder
# Step-2: Save the package
le=LabelEncoder()
# Step-3: Apply Fit transform
visa_df['has_job_experience']=le.fit_transform(visa_df['has_job_experience'])
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   0
# 1         EZYV02      Asia              Master's                   1
# 2         EZYV03      Asia            Bachelor's                   0
# 3         EZYV04      Asia            Bachelor's                   0
# 4         EZYV05    Africa              Master's                   1
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   1
# 25476  EZYV25477      Asia           High School                   1
# 25477  EZYV25478      Asia              Master's                   1
# 25478  EZYV25479      Asia              Master's                   1
# 25479  EZYV25480      Asia            Bachelor's                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Read the data
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")

# %%
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
cols=visa_df.select_dtypes(include='object').columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cols:
    visa_df[i]=le.fit_transform(visa_df[i])

visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **Inverse transform**
#
# - Inorder to see inverse of labels we need to perform individually

# %%
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

visa_df['case_status']=le.fit_transform(visa_df['case_status'])
print(visa_df['case_status'].values)  # why we are applying values
print(le.inverse_transform(visa_df['case_status']))
# Out:
# [1 0 1 ... 0 0 0]
# ['Denied' 'Certified' 'Denied' ... 'Certified' 'Certified' 'Certified']

# %% [markdown]
# **LabelEncoder will use most of the time**

# %% [markdown]
# **np.where method**
#
# - np.where is applicable only for binary
#
# - np.where will take 3 aruguments
#
#     - condition
#
#     - True value
#
#     - False value

# %% [markdown]
# $Secnario$
#
# - For example, case_status value equal to 'Certified', replace with Zero
#
# - Other wise, replace with 1

# %%
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")

# %%
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **One hot encoder**
#
# - One hot means if one is ON another is OFF
#
# - ON represents with 1, OFF represents with 0
#
# - For example case status has two unique labels
#
#     - Denied
#
#     - Certified
#
# - If we apply one hot encoder on case status column it will create two extra columns
#
#     - case_status_Denied
#
#     - case_status_Certified

# %% [markdown]
# |case_status|case_status_denied|case_status_certified|
# |---------|--|--|
# |Denied|1|0|
# |Certified|0|1|

# %% [markdown]
# **Advantages**
#
# - In machine learning we have one important property is **Independent of variables**
#
# - Machine learning models expects variables are independent to each other
#
# - One hot encoder creating new columns, the new columns are **independent each other**
#
# - Independent variables means both variables have **90 degrees phase shift**
#
# - 90 degrees phase shift also called as **perpendicular each other**
#
# - perpendicular means **orthogonal each other**

# %% [markdown]
# **Disadvantage**
#
# - One hot encoder creates new columns equal to unique labels
#
# - if number of unique labels increase, new columns also increase
#
# - The more columns leads data is more
#
# - Then data is more, the complexity will increase
#
# - The complexity increases, more computation power required
#
# - Also, time also increase
#
# - The entire process is called **Curse of dimensionality**

# %% [markdown]
# **pd.get_dummies**

# %% [markdown]
# - Read the data again
#
# - choose one column
#
# - apply pd.get_dummies

# %%
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")

# %%
pd.get_dummies(visa_df['prevailing_wage']).columns
# Out:
# Index([   2.1367,    2.9561,    3.0031,    3.3188,    3.4889,    5.0899,
#           5.1868,    5.4108,    5.6396,    6.3305,
#        ...
#        306021.96, 306206.67, 306982.28, 307410.02,  307716.1, 311734.49,
#        314156.06,  315497.6, 318446.05, 319210.27],
#       dtype='float64', length=25454)

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
pd.get_dummies(visa_df['case_status'],dtype='int')
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
import pandas as pd
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
pd.get_dummies(visa_df,dtype='int')

# %% [markdown]
# **Note**
#
# - Always drop the id columns

# %%
import pandas as pd
visa_df=pd.read_csv(r"C:\Users\gunda\Documents\Documents\Naresh IT\Data Science\Data files\visadataset.csv")
visa_df.drop('case_id',axis=1,inplace=True)
pd.get_dummies(visa_df,dtype='int')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  continent_Africa  \
# 0                14513         2007         592.2029                 0
# 1                 2412         2002       83425.6500                 0
# 2                44444         2008      122996.8600                 0
# 3                   98         1897       83434.0300                 0
# 4                 1082         2005      149907.3900                 1
# ...                ...          ...              ...               ...
# 25475             2601         2008       77092.5700                 0
# 25476             3274         2006      279174.7900                 0
# 25477             1121         1910      146298.8500                 0
# 25478             1918         1887       86154.7700                 0
# 25479             3195         1960       70876.9100                 0
#
#        continent_Asia  continent_Europe  continent_North America  \
# ...

# %% [markdown]
# - Generally we will prefer LabelEncoder
#
# - One hot encoder when categorical data has less unique labels
